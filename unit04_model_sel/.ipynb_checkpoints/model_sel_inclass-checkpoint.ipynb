# %% [markdown]
# # Model Selection In-Class Exercise
#
# In this example, you will a linear model to data and select the model order by model order selection.  First load the standard packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load the Data
#
# The data in this exercise is completely synthetic.  You can load it with the following commmand.

# %%
fn_src = 'https://raw.githubusercontent.com/sdrangan/introml/master/unit04_model_sel/synth_data.p'
fn_dst = 'synth_data.p'

import os
from six.moves import urllib

if os.path.isfile(fn_dst):
    print('File %s is already downloaded' % fn_dst)
else:        
    urllib.request.urlretrieve(fn_src, fn_dst)
    print('File %s downloaded' % fn_dst)

with open(fn_dst,'rb') as fp:
    x,y = pickle.load(fp)
# Out:
# File synth_data.p is already downloaded

# %% [markdown]
# Plot the data `y` vs. `x` using a scatter plot.

# %%
# TODO
plt.plot(x,y,'o')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

# %% [markdown]
# ## Fit the Data
#
# We will now try to fit the data.  First, split the data into training and test.  You can use the `train_test_split()` method in the `sklearn` package.

# %%
# TODO
xtr, xts, ytr, yts = train_test_split(x, y, test_size=0.5)

# %% [markdown]
# Now try to fit a linear model to the data.  You can pick any linear model with a variable number `d` of basis functions.  For example, you can use the polynomials up to degree `d-1`.
#
# For each model order `d`:
# * Fit the model on the training data
# * Test the model on the test data
#
# Plot the test error vs. `d`.  Select the model order `dopt` with the lowest test error.

# %%
# TODO
import numpy.polynomial.polynomial as poly

dtest = np.array(range(0,10))
RSStest = []

for d in dtest:
    # Fit data to a model of order d to training data
    beta_hat = poly.polyfit(xtr,ytr,d)
    # Estimate values of y with test data
    yhat = poly.polyval(xts,beta_hat)
    #score model based on error
    RSSd = np.mean((yhat-yts)**2)
    RSStest.append(RSSd)
plt.plot(dtest,RSStest,'o-')
plt.xlabel('model order,d')
plt.ylabel('model score (RSS)')
plt.grid()
# Out:
# 0.1735248497639135

# %% [markdown]
# Select the optimal model order `dopt`.  Re-train the model for that model order.  On one plot:
# * Plot the predicted value `yhat` vs. `x` for your model for `x in [0,35]`
# * Plot a scatter plot of the test data `xts` vs. `yts`
#
# Does your model fit the test data well?
# Does it extrapolate reasonably in the range `x >= 30`?

# %%
# TODO
dopt = dtest[np.argmin(RSStest)];
print(dopt)

beta_hat = poly.polyfit(xtr,ytr,dopt)
xplt = np.linspace(0,35)
yhat = poly.polyval(xplt,beta_hat)
plt.plot(xplt,yhat,'-')
plt.plot(xts,yts,'o')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
# Out:
# 7

# %%
dtest = np.arange(1,11);
utr, uts, ytr, yts = train_test_split(x, y, test_size=0.5)
n = len(utr)
model = LinearRegression()
RSStest = []

for d in dtest:
    pw = np.arange(0,d+1)
    phitr = np.exp(-utr/d)
    
    Xtr = phitr[:,None]**pw[None,:]
    model.fit(Xtr,ytr)

    phits = np.exp(-uts/d)
    Xts = phits[:,None]**pw[None,:]
    yhat = model.predict(Xts)
    RSSd = np.mean((yhat-yts)**2)
    RSStest.append(RSSd)

plt.plot(dtest,RSStest,'o-')
plt.xlabel('model order,d')
plt.ylabel('model score (RSS)')
plt.grid()
# Out:
# (100,)
# (100, 2)
# (100,)
# (100, 3)
# (100,)
# (100, 4)
# (100,)
# (100, 5)
# (100,)
# (100, 6)
# (100,)
# (100, 7)
# (100,)
# (100, 8)
# (100,)
# (100, 9)
# (100,)
# (100, 10)
# (100,)
# (100, 11)

# %%
dopt = dtest[np.argmin(RSStest)];
beta_hat = poly.polyfit(xtr,ytr,dopt)
xplt = np.linspace(0,35)
phiplt = np.exp(-xplt/dopt)
yhat = poly.polyval(phiplt,beta_hat)
plt.plot(xplt,yhat,'-')
plt.plot(uts,yts,'o')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

# %%
n=5
d = 3
test_d = np.arange(0,d+1)
print(test_d)

test_m = np.random.uniform(0,10,(n,d+1))
print(test_m)

print(test_m**test_d[None,:])
# Out:
# [0 1 2 3]
# [[4.40211124 3.95613725 7.6910434  4.14778735]
#  [7.10849106 3.99554585 0.15468197 9.9145971 ]
#  [1.29946124 8.54426655 0.3946236  0.80711641]
#  [5.91009335 2.89277812 4.29967885 4.49006561]
#  [0.16591607 4.12510324 0.59042547 0.62204872]]
# [[1.00000000e+00 3.95613725e+00 5.91521486e+01 7.13591138e+01]
#  [1.00000000e+00 3.99554585e+00 2.39265116e-02 9.74597318e+02]
#  [1.00000000e+00 8.54426655e+00 1.55727786e-01 5.25785415e-01]
#  [1.00000000e+00 2.89277812e+00 1.84872382e+01 9.05228172e+01]
#  [1.00000000e+00 4.12510324e+00 3.48602240e-01 2.40698405e-01]]
# [1.74673202 4.14482919 9.29936    6.46459164 0.30876417]

# %%
test_v = np.random.uniform(0,10,n)
print(test_v)

print(test_v[:,None]**test_d[None,:])
# Out:
# [9.58493596 0.08385224 4.05314737 0.41896526 2.30685254]
# [[1.00000000e+00 9.58493596e+00 9.18709974e+01 8.80577627e+02]
#  [1.00000000e+00 8.38522384e-02 7.03119789e-03 5.89581682e-04]
#  [1.00000000e+00 4.05314737e+00 1.64280036e+01 6.65851196e+01]
#  [1.00000000e+00 4.18965258e-01 1.75531888e-01 7.35417627e-02]
#  [1.00000000e+00 2.30685254e+00 5.32156866e+00 1.22760742e+01]]
